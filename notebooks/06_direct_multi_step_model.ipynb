# %% [markdown]
# # Purpose : Train Direct Multi-step Model
# - Purpose of this notebook is to build a direct multi-step model using LightGBM & Sklearn MultiOutputRegressor

# %%
# autoreload
# %load_ext autoreload
# %autoreload 2

# change current working directory to the root of the project
import os
os.chdir(os.path.dirname(os.getcwd()))

# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import joblib
import warnings
from tqdm import tqdm
from IPython.display import display

from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor

import lightgbm as lgb
import optuna

from src import data_manipulate, pipeline_transformers, plot

# %% [markdown]
# # Import Data

# %%
# import csv data into pandas dataframe
df_data = pd.read_csv('data/preprocessed/data_preprocessed.csv')
df_holidays = pd.read_csv('data/preprocessed/holidays_preprocessed.csv')
df_stores = pd.read_csv('data/preprocessed/stores_preprocessed.csv')
df_oil = pd.read_csv('data/preprocessed/oil_preprocessed.csv')
df_transactions = pd.read_csv('data/preprocessed/transactions_preprocessed.csv')

# %%
print(f'{df_data.shape=}')
display(df_data.head())
print(f'{df_holidays.shape=}')
display(df_holidays.head())
print(f'{df_oil.shape=}')
display(df_oil.head())
print(f'{df_stores.shape=}')
display(df_stores.head())
print(f'{df_transactions.shape=}')
display(df_transactions.head())
# Out:
# df_data.shape=(3008016, 5)
#        family  store_nbr        date  sales  onpromotion
# 0  AUTOMOTIVE          1  2013-01-01    0.0            0
# 1  AUTOMOTIVE          1  2013-01-02    2.0            0
# 2  AUTOMOTIVE          1  2013-01-03    3.0            0
# 3  AUTOMOTIVE          1  2013-01-04    3.0            0
# 4  AUTOMOTIVE          1  2013-01-05    5.0            0
# df_holidays.shape=(330, 6)
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# df_oil.shape=(1704, 2)
#          date  dcoilwtico
# 0  2013-01-01       93.14
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-05       93.12
# df_stores.shape=(54, 5)
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# df_transactions.shape=(83488, 3)
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %% [markdown]
# # Convert data to multi-output format

# %% [markdown]
# - **7 day prediction horizon with 0 lead time**

# %%
multi_steps = data_manipulate.make_multistep_target(df_data, steps=7, lead_time=0)
df_data = df_data.merge(multi_steps, left_index=True, right_index=True)
df_data
# Out:
#              family  store_nbr        date  sales  onpromotion  multi_step_1  \
# 0        AUTOMOTIVE          1  2013-01-01    0.0            0           0.0
# 1        AUTOMOTIVE          1  2013-01-02    2.0            0           2.0
# 2        AUTOMOTIVE          1  2013-01-03    3.0            0           3.0
# 3        AUTOMOTIVE          1  2013-01-04    3.0            0           3.0
# 4        AUTOMOTIVE          1  2013-01-05    5.0            0           5.0
# ...             ...        ...         ...    ...          ...           ...
# 3008005     SEAFOOD         54  2017-08-05    3.0            1           3.0
# 3008006     SEAFOOD         54  2017-08-06    0.0            0           0.0
# 3008007     SEAFOOD         54  2017-08-07    0.0            0           0.0
# 3008008     SEAFOOD         54  2017-08-08   12.0            0          12.0
# 3008009     SEAFOOD         54  2017-08-09    4.0            0           4.0
#
#          multi_step_2  multi_step_3  multi_step_4  multi_step_5  multi_step_6  \
# 0                 2.0           3.0           3.0           5.0           2.0
# 1                 3.0           3.0           5.0           2.0           0.0
# 2                 3.0           5.0           2.0           0.0           2.0
# 3                 5.0           2.0           0.0           2.0           2.0
# 4                 2.0           0.0           2.0           2.0           2.0
# ...               ...           ...           ...           ...           ...
# 3008005           0.0           0.0          12.0           4.0           2.0
# 3008006           0.0          12.0           4.0           2.0           0.0
# 3008007          12.0           4.0           2.0           0.0           1.0
# 3008008           4.0           2.0           0.0           1.0           2.0
# 3008009           2.0           0.0           1.0           2.0           0.0
#
#          multi_step_7
# 0                 0.0
# 1                 2.0
# 2                 2.0
# 3                 2.0
# 4                 3.0
# ...               ...
# 3008005           0.0
# 3008006           1.0
# 3008007           2.0
# 3008008           0.0
# 3008009           3.0
#
# [2997324 rows x 12 columns]

# %% [markdown]
# # Add features

# %% [markdown]
# - **Add lag features to the data**

# %%
df_data['date'] = pd.to_datetime(df_data['date'])

# join transaction data to df_data
df_transactions['date'] = pd.to_datetime(df_transactions['date'])
df_data = df_data.merge(df_transactions, on=['date', 'store_nbr'], how='left')

# join oil data to df_data
df_oil['date'] = pd.to_datetime(df_oil['date'])
df_data = df_data.merge(df_oil, on='date', how='left')

# %%
# add sales lag features
lag_features = data_manipulate.add_lag_features(df_data, column='sales', lags=28, lead_time=1)
df_data = df_data.merge(lag_features, left_index=True, right_index=True)

# drop sales column
df_data.drop(columns=['sales'], inplace=True)

# %%
# add oil lag features
lag_features = data_manipulate.add_lag_features(df_data, column='dcoilwtico', lags=28, lead_time=1)
df_data = df_data.merge(lag_features, left_index=True, right_index=True)

# drop dcoilwtico column
df_data.drop(columns=['dcoilwtico'], inplace=True)

# %%
# add transactions lag features
lag_features = data_manipulate.add_lag_features(df_data, column='transactions', lags=28, lead_time=1)
df_data = df_data.merge(lag_features, left_index=True, right_index=True)

# drop dcoilwtico column
df_data.drop(columns=['transactions'], inplace=True)

# %% [markdown]
# -  **Add store features**

# %%
# rename type column in holidays to holiday_type
df_stores.rename(columns={'type': 'store_type'}, inplace=True)

# merge store data with df_data
df_data = df_data.merge(df_stores, on='store_nbr', how='left')
df_data
# Out:
#              family  store_nbr       date  onpromotion  multi_step_1  \
# 0        AUTOMOTIVE          1 2013-01-01            0           0.0
# 1        AUTOMOTIVE          1 2013-01-02            0           2.0
# 2        AUTOMOTIVE          1 2013-01-03            0           3.0
# 3        AUTOMOTIVE          1 2013-01-04            0           3.0
# 4        AUTOMOTIVE          1 2013-01-05            0           5.0
# ...             ...        ...        ...          ...           ...
# 2997319     SEAFOOD         54 2017-08-05            1           3.0
# 2997320     SEAFOOD         54 2017-08-06            0           0.0
# 2997321     SEAFOOD         54 2017-08-07            0           0.0
# 2997322     SEAFOOD         54 2017-08-08            0          12.0
# 2997323     SEAFOOD         54 2017-08-09            0           4.0
#
#          multi_step_2  multi_step_3  multi_step_4  multi_step_5  multi_step_6  \
# 0                 2.0           3.0           3.0           5.0           2.0
# 1                 3.0           3.0           5.0           2.0           0.0
# 2                 3.0           5.0           2.0           0.0           2.0
# 3                 5.0           2.0           0.0           2.0           2.0
# 4                 2.0           0.0           2.0           2.0           2.0
# ...               ...           ...           ...           ...           ...
# 2997319           0.0           0.0          12.0           4.0           2.0
# 2997320           0.0          12.0           4.0           2.0           0.0
# 2997321          12.0           4.0           2.0           0.0           1.0
# 2997322           4.0           2.0           0.0           1.0           2.0
# 2997323           2.0           0.0           1.0           2.0           0.0
#
#          ...  transactions_lag_23  transactions_lag_24  transactions_lag_25  \
# 0        ...                  NaN                  NaN                  NaN
# 1        ...                  NaN                  NaN                  NaN
# 2        ...                  NaN                  NaN                  NaN
# 3        ...                  NaN                  NaN                  NaN
# 4        ...                  NaN                  NaN                  NaN
# ...      ...                  ...                  ...                  ...
# 2997319  ...                683.0                692.0                767.0
# 2997320  ...                676.0                683.0                692.0
# 2997321  ...                855.0                676.0                683.0
# 2997322  ...                920.0                855.0                676.0
# 2997323  ...                864.0                920.0                855.0
#
#          transactions_lag_26  transactions_lag_27  transactions_lag_28  \
# 0                        NaN                  NaN                  NaN
# 1                        NaN                  NaN                  NaN
# 2                        NaN                  NaN                  NaN
# 3                        NaN                  NaN                  NaN
# 4                        NaN                  NaN                  NaN
# ...                      ...                  ...                  ...
# 2997319                840.0               1027.0                917.0
# 2997320                767.0                840.0               1027.0
# 2997321                692.0                767.0                840.0
# 2997322                683.0                692.0                767.0
# 2997323                676.0                683.0                692.0
#
#               city      state  store_type  cluster
# 0            Quito  Pichincha           D       13
# 1            Quito  Pichincha           D       13
# 2            Quito  Pichincha           D       13
# 3            Quito  Pichincha           D       13
# 4            Quito  Pichincha           D       13
# ...            ...        ...         ...      ...
# 2997319  El Carmen     Manabi           C        3
# 2997320  El Carmen     Manabi           C        3
# 2997321  El Carmen     Manabi           C        3
# 2997322  El Carmen     Manabi           C        3
# 2997323  El Carmen     Manabi           C        3
#
# [2997324 rows x 99 columns]

# %% [markdown]
# - **Add holiday features**

# %%
# rename type column in holidays to holiday_type
df_holidays.rename(columns={'type': 'holiday_type'}, inplace=True)

# merge holiday data with df_data
df_holidays['date'] = pd.to_datetime(df_holidays['date'])
df_data = df_data.merge(df_holidays[['date', 'holiday_type', 'locale_name']], left_on=['city', 'date'], right_on=['locale_name', 'date'],  how='left')
df_data.drop(columns=['locale_name'], inplace=True)
df_data
# Out:
#              family  store_nbr       date  onpromotion  multi_step_1  \
# 0        AUTOMOTIVE          1 2013-01-01            0           0.0
# 1        AUTOMOTIVE          1 2013-01-02            0           2.0
# 2        AUTOMOTIVE          1 2013-01-03            0           3.0
# 3        AUTOMOTIVE          1 2013-01-04            0           3.0
# 4        AUTOMOTIVE          1 2013-01-05            0           5.0
# ...             ...        ...        ...          ...           ...
# 2997319     SEAFOOD         54 2017-08-05            1           3.0
# 2997320     SEAFOOD         54 2017-08-06            0           0.0
# 2997321     SEAFOOD         54 2017-08-07            0           0.0
# 2997322     SEAFOOD         54 2017-08-08            0          12.0
# 2997323     SEAFOOD         54 2017-08-09            0           4.0
#
#          multi_step_2  multi_step_3  multi_step_4  multi_step_5  multi_step_6  \
# 0                 2.0           3.0           3.0           5.0           2.0
# 1                 3.0           3.0           5.0           2.0           0.0
# 2                 3.0           5.0           2.0           0.0           2.0
# 3                 5.0           2.0           0.0           2.0           2.0
# 4                 2.0           0.0           2.0           2.0           2.0
# ...               ...           ...           ...           ...           ...
# 2997319           0.0           0.0          12.0           4.0           2.0
# 2997320           0.0          12.0           4.0           2.0           0.0
# 2997321          12.0           4.0           2.0           0.0           1.0
# 2997322           4.0           2.0           0.0           1.0           2.0
# 2997323           2.0           0.0           1.0           2.0           0.0
#
#          ...  transactions_lag_24  transactions_lag_25  transactions_lag_26  \
# 0        ...                  NaN                  NaN                  NaN
# 1        ...                  NaN                  NaN                  NaN
# 2        ...                  NaN                  NaN                  NaN
# 3        ...                  NaN                  NaN                  NaN
# 4        ...                  NaN                  NaN                  NaN
# ...      ...                  ...                  ...                  ...
# 2997319  ...                692.0                767.0                840.0
# 2997320  ...                683.0                692.0                767.0
# 2997321  ...                676.0                683.0                692.0
# 2997322  ...                855.0                676.0                683.0
# 2997323  ...                920.0                855.0                676.0
#
#          transactions_lag_27  transactions_lag_28       city      state  \
# 0                        NaN                  NaN      Quito  Pichincha
# 1                        NaN                  NaN      Quito  Pichincha
# 2                        NaN                  NaN      Quito  Pichincha
# 3                        NaN                  NaN      Quito  Pichincha
# 4                        NaN                  NaN      Quito  Pichincha
# ...                      ...                  ...        ...        ...
# 2997319               1027.0                917.0  El Carmen     Manabi
# 2997320                840.0               1027.0  El Carmen     Manabi
# 2997321                767.0                840.0  El Carmen     Manabi
# 2997322                692.0                767.0  El Carmen     Manabi
# 2997323                683.0                692.0  El Carmen     Manabi
#
#          store_type  cluster  holiday_type
# 0                 D       13           NaN
# 1                 D       13           NaN
# 2                 D       13           NaN
# 3                 D       13           NaN
# 4                 D       13           NaN
# ...             ...      ...           ...
# 2997319           C        3           NaN
# 2997320           C        3           NaN
# 2997321           C        3           NaN
# 2997322           C        3           NaN
# 2997323           C        3           NaN
#
# [2997324 rows x 100 columns]

# %% [markdown]
# - **Add Trend**

# %%
df_data['trend'] = df_data.groupby(['family', 'store_nbr']).cumcount()

# %%
print(f'{df_data.shape=}')
display(df_data.head())
# Out:
# df_data.shape=(2997324, 101)
#        family  store_nbr       date  onpromotion  multi_step_1  multi_step_2  \
# 0  AUTOMOTIVE          1 2013-01-01            0           0.0           2.0
# 1  AUTOMOTIVE          1 2013-01-02            0           2.0           3.0
# 2  AUTOMOTIVE          1 2013-01-03            0           3.0           3.0
# 3  AUTOMOTIVE          1 2013-01-04            0           3.0           5.0
# 4  AUTOMOTIVE          1 2013-01-05            0           5.0           2.0
#
#    multi_step_3  multi_step_4  multi_step_5  multi_step_6  ...  \
# 0           3.0           3.0           5.0           2.0  ...
# 1           3.0           5.0           2.0           0.0  ...
# 2           5.0           2.0           0.0           2.0  ...
# 3           2.0           0.0           2.0           2.0  ...
# 4           0.0           2.0           2.0           2.0  ...
#
#    transactions_lag_25  transactions_lag_26  transactions_lag_27  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    transactions_lag_28   city      state  store_type  cluster  holiday_type  \
# 0                  NaN  Quito  Pichincha           D       13           NaN
# 1                  NaN  Quito  Pichincha           D       13           NaN
# 2                  NaN  Quito  Pichincha           D       13           NaN
# 3                  NaN  Quito  Pichincha           D       13           NaN
# 4                  NaN  Quito  Pichincha           D       13           NaN
#
#    trend
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#
# [5 rows x 101 columns]

# %% [markdown]
# # Train Test split

# %%
X_train, y_train, X_test, y_test = data_manipulate.train_test_split_multi_step(df_data, cutoff_date='2017-01-01')

# %%
print(f'{X_train.shape=}')
display(X_train.head())
print(f'{y_train.shape=}')
display(y_train.head())
print(f'{X_test.shape=}')
display(X_test.head())
print(f'{y_test.shape=}')
display(y_test.head())
# Out:
# X_train.shape=(2603502, 94)
#        family  store_nbr       date  onpromotion  sales_lag_1  sales_lag_2  \
# 0  AUTOMOTIVE          1 2013-01-01            0          NaN          NaN
# 1  AUTOMOTIVE          1 2013-01-02            0          0.0          NaN
# 2  AUTOMOTIVE          1 2013-01-03            0          2.0          0.0
# 3  AUTOMOTIVE          1 2013-01-04            0          3.0          2.0
# 4  AUTOMOTIVE          1 2013-01-05            0          3.0          3.0
#
#    sales_lag_3  sales_lag_4  sales_lag_5  sales_lag_6  ...  \
# 0          NaN          NaN          NaN          NaN  ...
# 1          NaN          NaN          NaN          NaN  ...
# 2          NaN          NaN          NaN          NaN  ...
# 3          0.0          NaN          NaN          NaN  ...
# 4          2.0          0.0          NaN          NaN  ...
#
#    transactions_lag_25  transactions_lag_26  transactions_lag_27  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    transactions_lag_28   city      state  store_type  cluster  holiday_type  \
# 0                  NaN  Quito  Pichincha           D       13           NaN
# 1                  NaN  Quito  Pichincha           D       13           NaN
# 2                  NaN  Quito  Pichincha           D       13           NaN
# 3                  NaN  Quito  Pichincha           D       13           NaN
# 4                  NaN  Quito  Pichincha           D       13           NaN
#
#    trend
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#
# [5 rows x 94 columns]
# y_train.shape=(2603502, 7)
#    multi_step_1  multi_step_2  multi_step_3  multi_step_4  multi_step_5  \
# 0           0.0           2.0           3.0           3.0           5.0
# 1           2.0           3.0           3.0           5.0           2.0
# 2           3.0           3.0           5.0           2.0           0.0
# 3           3.0           5.0           2.0           0.0           2.0
# 4           5.0           2.0           0.0           2.0           2.0
#
#    multi_step_6  multi_step_7
# 0           2.0           0.0
# 1           0.0           2.0
# 2           2.0           2.0
# 3           2.0           2.0
# 4           2.0           3.0
# X_test.shape=(393822, 94)
#           family  store_nbr       date  onpromotion  sales_lag_1  sales_lag_2  \
# 1461  AUTOMOTIVE          1 2017-01-01            0          2.0          4.0
# 1462  AUTOMOTIVE          1 2017-01-02            0          0.0          2.0
# 1463  AUTOMOTIVE          1 2017-01-03            0          5.0          0.0
# 1464  AUTOMOTIVE          1 2017-01-04            0          4.0          5.0
# 1465  AUTOMOTIVE          1 2017-01-05            0          1.0          4.0
#
#       sales_lag_3  sales_lag_4  sales_lag_5  sales_lag_6  ...  \
# 1461          3.0         12.0          5.0          0.0  ...
# 1462          4.0          3.0         12.0          5.0  ...
# 1463          2.0          4.0          3.0         12.0  ...
# 1464          0.0          2.0          4.0          3.0  ...
# 1465          5.0          0.0          2.0          4.0  ...
#
#       transactions_lag_25  transactions_lag_26  transactions_lag_27  \
# 1461               2004.0                523.0               1887.0
# 1462               1828.0               2004.0                523.0
# 1463               1881.0               1828.0               2004.0
# 1464               1376.0               1881.0               1828.0
# 1465                572.0               1376.0               1881.0
#
#       transactions_lag_28   city      state  store_type  cluster  \
# 1461                568.0  Quito  Pichincha           D       13
# 1462               1887.0  Quito  Pichincha           D       13
# 1463                523.0  Quito  Pichincha           D       13
# 1464               2004.0  Quito  Pichincha           D       13
# 1465               1828.0  Quito  Pichincha           D       13
#
#       holiday_type  trend
# 1461           NaN   1461
# 1462           NaN   1462
# 1463           NaN   1463
# 1464           NaN   1464
# 1465           NaN   1465
#
# [5 rows x 94 columns]
# y_test.shape=(393822, 7)
#       multi_step_1  multi_step_2  multi_step_3  multi_step_4  multi_step_5  \
# 1461           0.0           5.0           4.0           1.0           2.0
# 1462           5.0           4.0           1.0           2.0           2.0
# 1463           4.0           1.0           2.0           2.0           5.0
# 1464           1.0           2.0           2.0           5.0           0.0
# 1465           2.0           2.0           5.0           0.0           2.0
#
#       multi_step_6  multi_step_7
# 1461           2.0           5.0
# 1462           5.0           0.0
# 1463           0.0           2.0
# 1464           2.0           3.0
# 1465           3.0          10.0

# %% [markdown]
# # Define Custom Pipeline

# %%
# select numerical features
num_cols = [col for col in X_train.columns if X_train[col].dtype in ['int64', 'float64']]
num_cols.append('average_rides_last_4_weeks')
# select categorical features
cat_cols = [col for col in X_train.columns if X_train[col].dtype in ['object']]
# select boolean features
bool_cols = [col for col in X_train.columns if X_train[col].dtype in ['bool']]

# %%
# check missing values in categorical features
df_data[cat_cols].isna().sum()
# Out:
# family                0
# city                  0
# state                 0
# store_type            0
# holiday_type    2985939
# dtype: int64

# %%
def custom_pipeline(**params):
    cat_cols_transformations = make_pipeline(
        pipeline_transformers.PandasSimpleImputer(strategy='constant', fill_value='no_holiday'), # only holiday_type column has missing values
        OneHotEncoder(handle_unknown='ignore')
    )

    num_cols_transformations = make_pipeline(
        pipeline_transformers.PandasSimpleImputer(strategy='median')
    )

    bool_cols_transformations = make_pipeline(
        OrdinalEncoder()
    )

    cols_trans = ColumnTransformer([
        ('bool', bool_cols_transformations, bool_cols),
        ('cat', cat_cols_transformations, cat_cols),
        ('num', num_cols_transformations, num_cols),
        ], remainder='passthrough'
        )

    pipeline = make_pipeline(
        pipeline_transformers.FourierFeatures(10),
        pipeline_transformers.add_temporal_features,
        pipeline_transformers.add_feature_average_rides_last_4_weeks,
        cols_trans,
        MinMaxScaler(),
        MultiOutputRegressor(lgb.LGBMRegressor(**params, verbose_eval=None))
        )
    
    return pipeline

# %% [markdown]
# # Hyper-parameter Tuning

# %%
# Define hyper-parameters & objective function
# define objective function
def objective(trial: optuna.trial.Trial) -> float:
    '''Takes in hyperparameters as input, and trains a model that computes the average validation error based on TimeSeriesSplit cross validation'''

    # define hyperparameters
    params = {
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
        "subsample": trial.suggest_float("subsample", 0.2, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 3, 100),   
    }

    tss = TimeSeriesSplit(n_splits=10)
    scores = []
    for train_index, val_index in tss.split(X_train):
        # split data
        X_train_, X_val = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_, y_val = y_train.iloc[train_index], y_train.iloc[val_index]

        # create model
        pipeline = custom_pipeline(**params)

        # fit model
        pipeline.fit(X_train_, y_train_)

        # compute validation error
        y_pred = pipeline.predict(X_val)
        mae = mean_absolute_error(y_val, y_pred)

        scores.append(mae)
    
    return np.mean(scores)

# %%
warnings.filterwarnings('ignore')

# optuna study
study = optuna.create_study(direction='minimize', study_name='direct_multistep_lightgbm')
study.optimize(objective, n_trials=10)
# Out:
# [I 2023-03-15 22:00:27,401] A new study created in memory with name: direct_multistep_lightgbm
# [I 2023-03-15 22:14:53,169] Trial 0 finished with value: 136.26015184914954 and parameters: {'num_leaves': 29, 'colsample_bytree': 0.9393940565830461, 'subsample': 0.5316825591994212, 'min_child_samples': 6}. Best is trial 0 with value: 136.26015184914954.
# [I 2023-03-15 22:29:11,406] Trial 1 finished with value: 136.09716445338344 and parameters: {'num_leaves': 32, 'colsample_bytree': 0.8936400886450608, 'subsample': 0.6621426029164286, 'min_child_samples': 6}. Best is trial 1 with value: 136.09716445338344.
# [I 2023-03-15 22:52:52,415] Trial 2 finished with value: 134.62540515190537 and parameters: {'num_leaves': 203, 'colsample_bytree': 0.5065526205015101, 'subsample': 0.3996726782329283, 'min_child_samples': 96}. Best is trial 2 with value: 134.62540515190537.
# [I 2023-03-15 23:08:41,613] Trial 3 finished with value: 134.77823066085227 and parameters: {'num_leaves': 75, 'colsample_bytree': 0.7298509445283272, 'subsample': 0.7315107729706323, 'min_child_samples': 37}. Best is trial 2 with value: 134.62540515190537.
# [I 2023-03-15 23:22:05,030] Trial 4 finished with value: 136.88878049318225 and parameters: {'num_leaves': 29, 'colsample_bytree': 0.6390091585741431, 'subsample': 0.892419824997664, 'min_child_samples': 81}. Best is trial 2 with value: 134.62540515190537.
# [I 2023-03-15 23:46:12,400] Trial 5 finished with value: 133.83970180402932 and parameters: {'num_leaves': 237, 'colsample_bytree': 0.775526308932724, 'subsample': 0.2737867982536908, 'min_child_samples': 82}. Best is trial 5 with value: 133.83970180402932.
# [I 2023-03-16 00:00:36,048] Trial 6 finished with value: 139.3426723178886 and parameters: {'num_leaves': 76, 'colsample_bytree': 0.2112697529053584, 'subsample': 0.7892249066610522, 'min_child_samples': 37}. Best is trial 5 with value: 133.83970180402932.
# [I 2023-03-16 00:14:04,012] Trial 7 finished with value: 136.13865801115793 and parameters: {'num_leaves': 31, 'colsample_bytree': 0.9560146654433617, 'subsample': 0.7844134268371017, 'min_child_samples': 28}. Best is trial 5 with value: 133.83970180402932.
# [I 2023-03-16 00:28:35,381] Trial 8 finished with value: 135.32263930325368 and parameters: {'num_leaves': 50, 'colsample_bytree': 0.9319357077122163, 'subsample': 0.5469143056222553, 'min_child_samples': 56}. Best is trial 5 with value: 133.83970180402932.
# [I 2023-03-16 00:43:16,007] Trial 9 finished with value: 136.24072829331757 and parameters: {'num_leaves': 41, 'colsample_bytree': 0.5724948208378882, 'subsample': 0.7445822490303922, 'min_child_samples': 85}. Best is trial 5 with value: 133.83970180402932.

# %%
# print best parameters
best_params = study.best_trial.params
print(f'{best_params=}')
# Out:
# best_params={'num_leaves': 237, 'colsample_bytree': 0.775526308932724, 'subsample': 0.2737867982536908, 'min_child_samples': 82}

# %%
# fit best params on full training set
pipeline = custom_pipeline(**best_params)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('fourierfeatures',
#                  <src.pipeline_transformers.FourierFeatures object at 0x140d0cdf0>),
#                 ('functiontransformer-1',
#                  FunctionTransformer(func=<function extract_temporal_features at 0x140479550>)),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function average_rides_last_4_weeks at 0x140453f70>)),
#                 ('columntransformer',
#                  ColumnTransformer(remainder...
#                                                    'sales_lag_21',
#                                                    'sales_lag_22',
#                                                    'sales_lag_23',
#                                                    'sales_lag_24',
#                                                    'sales_lag_25',
#                                                    'sales_lag_26',
#                                                    'sales_lag_27',
#                                                    'sales_lag_28', ...])])),
#                 ('minmaxscaler', MinMaxScaler()),
#                 ('multioutputregressor',
#                  MultiOutputRegressor(estimator=LGBMRegressor(colsample_bytree=0.775526308932724,
#                                                               min_child_samples=82,
#                                                               num_leaves=237,
#                                                               subsample=0.2737867982536908,
#                                                               verbose_eval=None)))])

# %%
import joblib
# save model using joblib
joblib.dump(pipeline, 'models/direct_multi_step_lightgbm.pkl')
# Out:
# ['models/direct_multi_step_lightgbm.pkl']

# %%
# load model using joblib
pipeline = joblib.load('models/direct_multi_step_lightgbm.pkl')

# %%
# compute test error on test set
predictions = pipeline.predict(X_test)

# convert negative predctions to 0
predictions[predictions < 0] = 0

predictions = pd.DataFrame(predictions, columns=y_test.columns, index=y_test.index)

display(y_test.head())
display(pd.DataFrame(predictions).head())

test_mae = mean_absolute_error(y_test, predictions)
print(f'{test_mae=:.4f}')
# Out:
# /Users/ani/Projects/2_retail_store_sales_forecasting/src/pipeline_transformers.py:39: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   X_['weekofyear'] = X_['date'].dt.weekofyear
#       multi_step_1  multi_step_2  multi_step_3  multi_step_4  multi_step_5  \
# 1461           0.0           5.0           4.0           1.0           2.0
# 1462           5.0           4.0           1.0           2.0           2.0
# 1463           4.0           1.0           2.0           2.0           5.0
# 1464           1.0           2.0           2.0           5.0           0.0
# 1465           2.0           2.0           5.0           0.0           2.0
#
#       multi_step_6  multi_step_7
# 1461           2.0           5.0
# 1462           5.0           0.0
# 1463           0.0           2.0
# 1464           2.0           3.0
# 1465           3.0          10.0
#       multi_step_1  multi_step_2  multi_step_3  multi_step_4  multi_step_5  \
# 1461      0.000000      8.386125      7.157858     13.794421      5.781627
# 1462      9.373171      9.453644     19.764002     18.273298      1.728217
# 1463      2.757471      9.565822      3.798612      2.729542      1.606704
# 1464      5.952292      3.977594      3.938922      2.198665      2.221066
# 1465      1.977377      1.906228      2.689992      2.334052      2.122923
#
#       multi_step_6  multi_step_7
# 1461      5.421441     12.021247
# 1462      4.689914      9.704564
# 1463      5.836518      2.736304
# 1464      3.459804      1.937692
# 1465      2.858194      3.426844
# test_mae=74.5421

# %% [markdown]
# # Plot Predictions

# %%
warnings.filterwarnings('ignore')

# join predictions to X_test store_nbr and family

prediction_test_set = X_test[['store_nbr', 'family', 'date']].merge(pd.DataFrame(predictions), left_index=True, right_index=True, how='left')
prediction_test_set.rename(columns={0: 'multi_step_1', 1: 'multi_step_2', 2: 'multi_step_3', 3: 'multi_step_4', 4: 'multi_step_5', 5: 'multi_step_6', 6: 'multi_step_7'}, inplace=True)

# join y_test to X_test store_nbr and family
actual_test_set = X_test[['store_nbr', 'family', 'date']].merge(y_test, left_index=True, right_index=True, how='left')

# %%
plot.plot_predictions(prediction_test_set, actual_test_set, 5, 'GROCERY I')

# %% [markdown]
# # Summary
# - **Direct Multi-step**
#     - MAE = 74.5421
